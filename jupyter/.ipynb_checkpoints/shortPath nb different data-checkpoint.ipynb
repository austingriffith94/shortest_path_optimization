# %%
# Austin Griffith
# Python 3.6.5
# 4/25/2018

import pandas as pd
import numpy as np
from gurobipy import *
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import networkx as nx

# %%
# set up plotting parameters
params = {'legend.fontsize': 20,
          'figure.figsize': (13,9),
         'axes.labelsize': 20,
         'axes.titlesize':20,
         'xtick.labelsize':15,
         'ytick.labelsize':15}
pylab.rcParams.update(params)

# %%
# graph all nodes and paths
def networkCompletePlot(solution,maxNode):
    G = nx.DiGraph()
    G.add_nodes_from(range(0,maxNode+1))
    for i,j in nodes:
        G.add_edge(i,j)

    # get solution nodes
    sp = [i for i,j in solution[1]]
    sp.append(end)

    colorNode = ['white' if not node in sp else 'red' for node in G.nodes()]
    title = 'Complete Network: Gamma = '+str(int(solution[0]))+', Opt Obj = '+str(round(solution[2],5))
    nx.draw_networkx(G,node_color=colorNode,node_size=200)
    plt.axis('off')
    plt.title(title)
    plt.show()

# graph path, with costs on edges
def networkPathPlot(solution,maxNode,cost):
    # get solution nodes
    sp = [i for i,j in solution[1]]
    sp.append(end)

    # set up random position values
    a = np.arange(maxNode+1)
    b = np.arange(maxNode+1)
    np.random.shuffle(a)
    posArray = np.array([a,b]).transpose()

    positions = {}
    for p in range(0,len(sp)):
        L = posArray[p]
        positions[sp[p]] = (L[0],L[1])

    # set up network graph
    G = nx.DiGraph()
    G.add_nodes_from(sp)

    for i,j in tuplelist(solution[1]):
        G.add_edge(i,j)

    labels = {}
    for i in solution[1]:
        labels[i] = round(c[i],3)

    title = 'Optimal Path: Gamma = '+str(int(solution[0]))+', Opt Obj = '+str(round(solution[2],5))
    nx.draw_networkx(G,positions,node_size=350)
    nx.draw_networkx_edge_labels(G,positions,edge_labels=labels)
    plt.axis('off')
    plt.title(title)
    plt.show()

# %%
# pull data
edges = pd.read_csv('edge_values.csv')
edges['i'] = np.int64(edges['i'])
edges['j'] = np.int64(edges['j'])

# create dictionaries of edge values
c = {}
d = {}
nodes = tuplelist()
for i in edges.index:
    c[edges['i'][i],edges['j'][i]] = edges['c(ij)'][i]
    d[edges['i'][i],edges['j'][i]] = edges['d(ij)'][i]
    nodes.append((edges['i'][i],edges['j'][i]))

maxNodes = max(edges['j'])
minNodes = min(edges['i'])

# %%
# choose start and end nodes
start = 0
end = int(maxNodes)

# allowed edge congestions
gend = 4
gammas = np.linspace(0,gend,gend+1)
print('Allowed Congestions:')
print(gammas)
# Out:
# Allowed Congestions:
# [ 0.  1.  2.  3.  4.]

# %%
# initialize model
model = Model('Shortest_Path')

# set up x binary variables, set to each location/movement
xVars = model.addVars(nodes, vtype=GRB.BINARY, name='move')
y0 = model.addVar(vtype=GRB.CONTINUOUS, name='y0')
zVars = model.addVars(nodes, lb=0.0, vtype=GRB.CONTINUOUS, name='cong')
model.update()

# %%
# constrain all entrance and exit nodes
enterStart = []
leaveStart = []
enterEnd = []
leaveEnd = []
for n in nodes:
    # for start nodes
    if n[0] == start:
        leaveStart.append(xVars[n])
    elif n[1] == start:
        enterStart.append(xVars[n])
    # for end nodes
    if n[0] == end:
        leaveEnd.append(xVars[n])
    elif n[1] == end:
        enterEnd.append(xVars[n])

model.addConstr(quicksum(leaveStart) == 1)
model.addConstr(quicksum(enterStart) == 0)
model.addConstr(quicksum(leaveEnd) == 0)
model.addConstr(quicksum(enterEnd) == 1)
model.update()

# %%
# gather all paths
paths = []
for i in range(minNodes+1,maxNodes):
    pathFrom = []
    pathTo = []
    for n in nodes:
        if n[0] == i:
            pathFrom.append(xVars[n])
        elif n[1] == i:
            pathTo.append(xVars[n])
    paths.append([pathFrom,pathTo])
model.update()

for p in paths:
    model.addConstr(quicksum(p[0]) - quicksum(p[1]) == 0.0)
model.update()

print('Example of Path Constraint for a Given Node:')
print(quicksum(p[0]) - quicksum(p[1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-0d6c67f5fb9c> in <module>()
#       1 # gather all paths
#       2 paths = []
# ----> 3 for i in range(minNodes+1,maxNodes):
#       4     pathFrom = []
#       5     pathTo = []
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
# objective function
costObj = []
for n in nodes:
    costObj.append(xVars[n]*c[n])
    model.addConstr(zVars[n] >= xVars[n]*d[n] - y0)
model.update()

print('Example of Congestion Constraint:')
print(zVars[n],' >= ',xVars[n]*d[n] - y0)
# Out:
# Example of Congestion Constraint:
# <gurobi.Var cong[45,44]>  >=  <gurobi.LinExpr: 3.7423124660000004 move[45,44] + -1.0 y0>

# %%
# iterate optimization through various gammas (congestions)
output = []
for g in gammas:
    # optimize
    objective = quicksum(costObj) + g*y0 + quicksum(zVars)
    model.setObjective(objective, GRB.MINIMIZE)

    model.optimize()

    # order the printout of optimal edges
    moves = []
    for m in xVars:
        if xVars[m].x != 0:
            moves.append(m)
    order = [moves[0]]
    for i in range(len(moves)):
        for m in moves:
            if order[i][1] == m[0]:
                order.append(m)
    output.append([g,order,model.objVal])
# Out:
# Optimize a model with 1916 rows, 3737 columns and 9340 nonzeros
# Variable types: 1869 continuous, 1868 integer (1868 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 5e+00]
#   Objective range  [3e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1.1131062
# Presolve removed 1870 rows and 1949 columns
# Presolve time: 0.01s
# Presolved: 46 rows, 1788 columns, 3576 nonzeros
# Variable types: 0 continuous, 1788 integer (1788 binary)
#
# Root relaxation: objective 1.400714e-01, 17 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.1400714    0.14007  0.00%     -    0s
#
# Explored 0 nodes (17 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.140071 1.11311
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400713960000e-01, best bound 1.400713960000e-01, gap 0.0000%
# Optimize a model with 1916 rows, 3737 columns and 9340 nonzeros
# Variable types: 1869 continuous, 1868 integer (1868 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 5e+00]
#   Objective range  [3e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded MIP start with objective 3.14007
#
# Presolve removed 82 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1834 rows, 3577 columns, 8940 nonzeros
# Variable types: 1789 continuous, 1788 integer (1788 binary)
#
# Root relaxation: objective 6.176308e-01, 96 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.61763    0   53    3.14007    0.61763  80.3%     -    0s
# H    0     0                       2.0261772    0.61763  69.5%     -    0s
#      0     0    0.75959    0   41    2.02618    0.75959  62.5%     -    0s
#      0     0    0.84132    0   22    2.02618    0.84132  58.5%     -    0s
# H    0     0                       1.5048832    0.84132  44.1%     -    0s
#      0     0    0.97094    0   18    1.50488    0.97094  35.5%     -    0s
#      0     0    1.03733    0   13    1.50488    1.03733  31.1%     -    0s
#      0     0    1.15140    0   22    1.50488    1.15140  23.5%     -    0s
#      0     0    1.15140    0   11    1.50488    1.15140  23.5%     -    0s
#      0     0    1.25391    0   15    1.50488    1.25391  16.7%     -    0s
#      0     0    1.43785    0   12    1.50488    1.43785  4.45%     -    0s
#      0     0    1.43785    0   17    1.50488    1.43785  4.45%     -    0s
#      0     0    1.43785    0   11    1.50488    1.43785  4.45%     -    0s
#      0     0    1.43785    0   11    1.50488    1.43785  4.45%     -    0s
#      0     0    1.43785    0    9    1.50488    1.43785  4.45%     -    0s
#      0     0    1.43785    0    9    1.50488    1.43785  4.45%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#
# Explored 1 nodes (424 simplex iterations) in 0.26 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1.50488 2.02618 3.14007
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.504883197000e+00, best bound 1.504883197000e+00, gap 0.0000%
# Optimize a model with 1916 rows, 3737 columns and 9340 nonzeros
# Variable types: 1869 continuous, 1868 integer (1868 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 5e+00]
#   Objective range  [3e-04, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded MIP start with objective 2.29622
#
# Presolve removed 82 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1834 rows, 3577 columns, 8940 nonzeros
# Variable types: 1789 continuous, 1788 integer (1788 binary)
#
# Root relaxation: objective 8.925107e-01, 72 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.89251    0   47    2.29622    0.89251  61.1%     -    0s
#      0     0    1.23196    0   43    2.29622    1.23196  46.3%     -    0s
#      0     0    1.23196    0   31    2.29622    1.23196  46.3%     -    0s
# H    0     0                       1.6712662    1.23196  26.3%     -    0s
#      0     0    1.30434    0   35    1.67127    1.30434  22.0%     -    0s
#      0     0    1.33975    0   27    1.67127    1.33975  19.8%     -    0s
#      0     0    1.53590    0   11    1.67127    1.53590  8.10%     -    0s
#      0     0    1.55783    0    3    1.67127    1.55783  6.79%     -    0s
#      0     0    1.65180    0    2    1.67127    1.65180  1.16%     -    0s
#
# Explored 1 nodes (410 simplex iterations) in 0.16 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.67127 2.29622
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.671266183000e+00, best bound 1.671266183000e+00, gap 0.0000%
# Optimize a model with 1916 rows, 3737 columns and 9340 nonzeros
# Variable types: 1869 continuous, 1868 integer (1868 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 5e+00]
#   Objective range  [3e-04, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded MIP start with objective 1.82138
#
# Presolve removed 82 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1834 rows, 3577 columns, 8940 nonzeros
# Variable types: 1789 continuous, 1788 integer (1788 binary)
#
# Root relaxation: objective 1.206956e+00, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.20696    0   44    1.82138    1.20696  33.7%     -    0s
#      0     0    1.56091    0   25    1.82138    1.56091  14.3%     -    0s
#      0     0    1.56091    0   23    1.82138    1.56091  14.3%     -    0s
#      0     0    1.67653    0   16    1.82138    1.67653  7.95%     -    0s
#      0     0    1.68855    0    3    1.82138    1.68855  7.29%     -    0s
# H    0     0                       1.7343907    1.68855  2.64%     -    0s
# *    0     0               0       1.6972650    1.69726  0.00%     -    0s
#
# Explored 1 nodes (208 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1.69726 1.73439 1.82138
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.697264992000e+00, best bound 1.697264992000e+00, gap 0.0000%
# Optimize a model with 1916 rows, 3737 columns and 9340 nonzeros
# Variable types: 1869 continuous, 1868 integer (1868 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 5e+00]
#   Objective range  [3e-04, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded MIP start with objective 1.72326
#
# Presolve removed 82 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1834 rows, 3577 columns, 8940 nonzeros
# Variable types: 1789 continuous, 1788 integer (1788 binary)
#
# Root relaxation: objective 1.399358e+00, 83 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.39936    0   48    1.72326    1.39936  18.8%     -    0s
# *    0     0               0       1.6972650    1.69726  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Clique: 2
#
# Explored 1 nodes (105 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.69726 1.72326
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.697264992000e+00, best bound 1.697264992000e+00, gap 0.0000%

# %%
# print optimal values and paths, plot network
for o in output:
    print('\nFor Gamma: '+str(o[0]))
    print('Path:')
    print(o[1])
    print('Cost of Movement (Objective):')
    print(o[2])
    networkCompletePlot(o,maxNodes)
    networkPathPlot(o,maxNodes,c)
# Out:
# For Gamma: 0.0
# Path:
# [(0, 35), (35, 15), (15, 45)]
# Cost of Movement (Objective):
# 0.14007139600000001
# For Gamma: 1.0
# Path:
# [(0, 14), (14, 43), (43, 21), (21, 45)]
# Cost of Movement (Objective):
# 1.5048831969999998
# For Gamma: 2.0
# Path:
# [(0, 5), (5, 37), (37, 45)]
# Cost of Movement (Objective):
# 1.671266183
# For Gamma: 3.0
# Path:
# [(0, 5), (5, 37), (37, 45)]
# Cost of Movement (Objective):
# 1.6972649919999998
# For Gamma: 4.0
# Path:
# [(0, 5), (5, 37), (37, 45)]
# Cost of Movement (Objective):
# 1.697264992
